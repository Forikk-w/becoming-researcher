# %%
import torch
from torch import nn
from torch.nn import functional as F
#无参数层
class CenteredLayer(nn.Module) :
    def __init__(self) :

        super().__init__()

    def forward(self, X) :
        return X - X.mean()

layer = CenteredLayer()
layer(torch.FloatTensor([1, 2, 3, 4, 5]))
# Out:
# tensor([-2., -1.,  0.,  1.,  2.])

# %%
#带参数
class MyLinear(nn.Module) :
    def __init__(self, in_units, units) :
        super().__init__()
        self.weight = nn.Parameter(torch.randn(in_units, units)) #参数都是Parameters的实例
        self.bias = nn.Parameter(torch.randn(in_units, ))
    def forward(self, X) :
        linear = torch.matmul(X, self.weight.data) + self.bias.data
        return F.relu(linear)
dense = MyLinear(5, 3)
dense.weight
# Out:
# Parameter containing:
# tensor([[ 1.2474, -0.7580,  0.1489],
#         [ 0.3771,  1.1846, -1.5556],
#         [-0.4525, -0.7247, -0.8461],
#         [ 0.4263, -1.2113,  1.2493],
#         [ 1.4005,  0.4134, -0.8424]], requires_grad=True)
